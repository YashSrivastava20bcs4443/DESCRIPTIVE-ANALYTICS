# %%
import csv
file = open('20bcs4443_Yash_Srivastava.csv')

type(file)
csvreader = csv.reader(file)

# %%
header = []
header = next(csvreader)
header
# Out:
# ['ï»¿age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal',
#  'target']

# %%
rows = []
for row in csvreader:
        rows.append(row)
rows
# Out:
# [['63',
#   '1',
#   '3',
#   '145',
#   '233',
#   '1',
#   '0',
#   '150',
#   '0',
#   '2.3',
#   '0',
#   '0',
#   '1',
#   '1'],
#  ['37',
#   '1',
#   '2',
#   '130',
#   '250',
#   '0',
#   '1',
#   '187',
#   '0',
#   '3.5',
#   '0',
#   '0',
#   '2',
#   '1'],
#  ['41',
#   '0',
#   '1',
#   '130',
#   '204',
#   '0',
#   '0',
#   '172',
#   '0',
#   '1.4',
#   '2',
#   '0',
#   '2',
#   '1'],
#  ['56',
#   '1',
#   '1',
#   '120',
#   '236',
#   '0',
#   '1',
#   '178',
#   '0',
#   '0.8',
#   '2',
#   '0',
#   '2',
#   '1'],
#  ['57',
#   '0',
#   '0',
#   '120',
#   '354',
#   '0',
#   '1',
#   '163',
#   '1',
#   '0.6',
#   '2',
#   '0',
#   '2',
#   '1'],
#  ['57',
#   '1',
#   '0',
#   '140',
#   '192',
#   '0',
#   '1',
#   '148',
#   '0',
#   '0.4',
#   '1',
#   '0',
#   '1',
#   '1'],
#  ['56',
#   '0',
#   '1',
#   '140',
#   '294',
#   '0',
#   '0',
#   '153',
#   '0',
#   '1.3',
#   '1',
#   '0',
#   '2',
#   '1'],
# ...

# %%
import pandas as pd
data= pd.read_csv("heart.csv",sep = ';')

# %%
data.head()
# Out:
#   age,sex,cp,trestbps,chol,fbs,restecg,thalach,exang,oldpeak,slope,ca,thal,target
# 0               63,1,3,145,233,1,0,150,0,2.3,0,0,1,1
# 1               37,1,2,130,250,0,1,187,0,3.5,0,0,2,1
# 2               41,0,1,130,204,0,0,172,0,1.4,2,0,2,1
# 3               56,1,1,120,236,0,1,178,0,0.8,2,0,2,1
# 4               57,0,0,120,354,0,1,163,1,0.6,2,0,2,1

# %%
data.tail()
# Out:
#     age,sex,cp,trestbps,chol,fbs,restecg,thalach,exang,oldpeak,slope,ca,thal,target
# 298               57,0,0,140,241,0,1,123,1,0.2,1,0,3,0
# 299               45,1,3,110,264,0,1,132,0,1.2,1,0,3,0
# 300               68,1,0,144,193,1,1,141,0,3.4,1,2,3,0
# 301               57,1,0,130,131,0,1,115,1,1.2,1,1,3,0
# 302                 57,0,1,130,236,0,0,174,0,0,1,1,2,0

# %%
print(data.iloc[1:3])
# Out:
#   age,sex,cp,trestbps,chol,fbs,restecg,thalach,exang,oldpeak,slope,ca,thal,target
# 1               37,1,2,130,250,0,1,187,0,3.5,0,0,2,1
# 2               41,0,1,130,204,0,0,172,0,1.4,2,0,2,1

# %%
import pandas as pd
dataframe1 = pd.read_excel('20bcs4443_Yash_Srivastava.xlsx')
print(dataframe1)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
dataframe1.iloc[0]['Active']
# Out:
# 9796

# %%
rows = dataframe1.shape[0]
print("Rows: " + str(rows))
# Out:
# Rows: 187

# %%
cols = dataframe1.shape[1]
print("Columns: " + str(cols))
# Out:
# Columns: 15

# %%
print(dataframe1.columns)
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
print(dataframe1.Confirmed)
# Out:
# 0      36263
# 1       4880
# 2      27973
# 3        907
# 4        950
#        ...
# 182    10621
# 183       10
# 184     1691
# 185     4552
# 186     2704
# Name: Confirmed, Length: 187, dtype: int64
